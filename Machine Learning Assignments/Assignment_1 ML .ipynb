# %% [markdown]
# # Dataset: Telecom Churn Dataset (Telecom_churn_data.csv)

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data=pd.read_csv("Z:\Purva226518_2sem\Machine Lear\Dataset\WA_Fn-UseC_-Telco-Customer-Churn.csv")
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.info
# Out:
# <bound method DataFrame.info of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
#Q2
#checking datatypes
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#2 changing data type
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'],errors='coerce')
data['TotalCharges'] = data['TotalCharges'].astype("float")
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
col=['customerID','gender','SeniorCitizen','Partner','Dependents','tenure','PhoneService','MultipleLines','InternetService',
    'OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract',
     'PaperlessBilling','PaymentMethod','MonthlyCharges','TotalCharges','Churn']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in col:
    data[i]=le.fit_transform(data[i])
data
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5375       0              0        1           0       1
# 1        3962       1              0        0           0      34
# 2        2564       1              0        0           0       2
# 3        5535       1              0        0           0      45
# 4        6511       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
data.isna().sum() #Missing values count
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Missing Values
data.isna().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
data.dropna(axis=1) #we can drop missing colm and row, axis=1 then drop whole colm and axis=0 then drop row
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
#Duplicate Values
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Length: 7043, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#removing Duplicates
data.drop_duplicates()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
# 4 Find out the churn based on contract and 
import matplotlib.ticker as mtick
contract_churn=data.groupby(['Contract','Churn']).size().unstack()
contract_churn
# Out:
# Churn        0     1
# Contract
# 0         2220  1655
# 1         1307   166
# 2         1647    48

# %%
#paperlessbilling attribute
contract_churn=data.groupby(['Churn','PaperlessBilling']).size().unstack()
contract_churn
# Out:
# PaperlessBilling     0     1
# Churn
# 0                 2403  2771
# 1                  469  1400

# %%
#Plot histograms for Tenure, TotalCharges and Monthlycharges . 
plt.hist(data.tenure)
# Out:
# (array([1612.,  759.,  570.,  556.,  495.,  494.,  452.,  495.,  501.,
#         1109.]),
#  array([ 0. ,  7.2, 14.4, 21.6, 28.8, 36. , 43.2, 50.4, 57.6, 64.8, 72. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data.TotalCharges)
# Out:
# (array([971., 708., 694., 675., 673., 669., 666., 662., 660., 665.]),
#  array([   0.,  653., 1306., 1959., 2612., 3265., 3918., 4571., 5224.,
#         5877., 6530.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data.MonthlyCharges)
# Out:
# (array([1682.,  409.,  625.,  446.,  615.,  855.,  776.,  654.,  640.,
#          341.]),
#  array([   0. ,  158.4,  316.8,  475.2,  633.6,  792. ,  950.4, 1108.8,
#         1267.2, 1425.6, 1584. ]),
#  <BarContainer object of 10 artists>)

# %%
data1 = data[['tenure','TotalCharges','MonthlyCharges']]
a=data1.plot.hist(bins=10,title='Tenure, TotalCharges and Monthlycharges')

# %%
#Display density plot  for TotalCharges vs  Churn(Yes/No) and MonthlyCharges vs 	churn(Yes/No)
import seaborn as sns
contract_churn.reset_index(inplace=True)

# %%
sns.set(style='darkgrid')
fig=sns.kdeplot('TotalCharges',hue='Churn',data=data,shade=True,color='r')

# %%
fig=sns.kdeplot('MonthlyCharges',hue='Churn',data=data,shade=True,color='r')

# %% [markdown]
# # Dataset: IoT Devices Data (IOT_Temprature.csv)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv(r"Z:\Darshan06_2sem\Machine Lear\Dataset\IOT-temp.csv")
df
# Out:
#                                         id  room_id/id        noted_date  \
# 0      __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30
# 1      __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30
# 2      __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29
# 3      __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29
# 4      __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29
# ...                                    ...         ...               ...
# 97601   __export__.temp_log_91076_7fbd08ca  Room Admin  28-07-2018 07:07
# 97602  __export__.temp_log_147733_62c03f31  Room Admin  28-07-2018 07:07
# 97603  __export__.temp_log_100386_84093a68  Room Admin  28-07-2018 07:06
# 97604  __export__.temp_log_123297_4d8e690b  Room Admin  28-07-2018 07:06
# 97605  __export__.temp_log_133741_32958703  Room Admin  28-07-2018 07:06
#
#        temp out/in
# 0        29     In
# 1        29     In
# 2        41    Out
# ...

# %%
df.head()
# Out:
#                                     id  room_id/id        noted_date  temp  \
# 0  __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30    29
# 1  __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30    29
# 2  __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29    41
# 3  __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29    41
# 4  __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29    31
#
#   out/in
# 0     In
# 1     In
# 2    Out
# 3    Out
# 4     In

# %%
df.dtypes
# Out:
# id            object
# room_id/id    object
# noted_date    object
# temp           int64
# out/in        object
# dtype: object

# %%
#Check the attributes data types and Drop out unwanted columns like id , room_id.
df.drop(['id','room_id/id'],axis=1)
# Out:
#              noted_date  temp out/in
# 0      08-12-2018 09:30    29     In
# 1      08-12-2018 09:30    29     In
# 2      08-12-2018 09:29    41    Out
# 3      08-12-2018 09:29    41    Out
# 4      08-12-2018 09:29    31     In
# ...                 ...   ...    ...
# 97601  28-07-2018 07:07    31     In
# 97602  28-07-2018 07:07    31     In
# 97603  28-07-2018 07:06    31     In
# 97604  28-07-2018 07:06    31     In
# 97605  28-07-2018 07:06    31     In
#
# [97606 rows x 3 columns]

# %%
#Check for missing values in any of the columns.
df.isna().sum()
# Out:
# id            0
# room_id/id    0
# noted_date    0
# temp          0
# out/in        0
# dtype: int64

# %%
#Separate out date and time values of noted_date column.
df.rename(columns={'noted_date':'datetime'},inplace=True)
df
# Out:
#                                         id  room_id/id          datetime  \
# 0      __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30
# 1      __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30
# 2      __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29
# 3      __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29
# 4      __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29
# ...                                    ...         ...               ...
# 97601   __export__.temp_log_91076_7fbd08ca  Room Admin  28-07-2018 07:07
# 97602  __export__.temp_log_147733_62c03f31  Room Admin  28-07-2018 07:07
# 97603  __export__.temp_log_100386_84093a68  Room Admin  28-07-2018 07:06
# 97604  __export__.temp_log_123297_4d8e690b  Room Admin  28-07-2018 07:06
# 97605  __export__.temp_log_133741_32958703  Room Admin  28-07-2018 07:06
#
#        temp out/in
# 0        29     In
# 1        29     In
# 2        41    Out
# ...

# %%
df['date']=pd.to_datetime(df['datetime']).dt.date
df['time']=pd.to_datetime(df['datetime']).dt.time
df
# Out:
#                                         id  room_id/id          datetime  \
# 0      __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30
# 1      __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30
# 2      __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29
# 3      __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29
# 4      __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29
# ...                                    ...         ...               ...
# 97601   __export__.temp_log_91076_7fbd08ca  Room Admin  28-07-2018 07:07
# 97602  __export__.temp_log_147733_62c03f31  Room Admin  28-07-2018 07:07
# 97603  __export__.temp_log_100386_84093a68  Room Admin  28-07-2018 07:06
# 97604  __export__.temp_log_123297_4d8e690b  Room Admin  28-07-2018 07:06
# 97605  __export__.temp_log_133741_32958703  Room Admin  28-07-2018 07:06
#
#        temp out/in        date      time
# 0        29     In  2018-08-12  09:30:00
# ...

# %%
#Further separate date,month,year from date and store as separate columns. Display the 	complete data with new columns. 
df['day']=pd.to_datetime(df['date']).dt.day
df['month']=pd.to_datetime(df['date']).dt.month
df['year']=pd.to_datetime(df['date']).dt.year
df
# Out:
#                                         id  room_id/id          datetime  \
# 0      __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30
# 1      __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30
# 2      __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29
# 3      __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29
# 4      __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29
# ...                                    ...         ...               ...
# 97601   __export__.temp_log_91076_7fbd08ca  Room Admin  28-07-2018 07:07
# 97602  __export__.temp_log_147733_62c03f31  Room Admin  28-07-2018 07:07
# 97603  __export__.temp_log_100386_84093a68  Room Admin  28-07-2018 07:06
# 97604  __export__.temp_log_123297_4d8e690b  Room Admin  28-07-2018 07:06
# 97605  __export__.temp_log_133741_32958703  Room Admin  28-07-2018 07:06
#
#        temp out/in        date      time  day  month  year
# ...

# %%
#Prepare boxplot of temperature. 
sns.boxplot(x=df['temp'])
# Out:
# <AxesSubplot:xlabel='temp'>

# %%
#Prepare barplot for in/out vs temprature. 
sns.barplot(y=df['temp'],x=df['out/in'])
# Out:
# <AxesSubplot:xlabel='out/in', ylabel='temp'>

# %% [markdown]
# # Dataset:  NYC AirBnB Dataset (AB_NYC_2019.csv)

# %%
#1.	Display structure and summary report. 
data=pd.read_csv(r"Z:\Darshan06_2sem\Machine Lear\Dataset\AB_NYC_2019.csv")
data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#2.Check data types of each column and ensure whether the data types for each of the 
#attributes are appropriate, if not make appropriate corrections. 
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
#3.Display NULL values for each of the columns
data.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#4.replace them for the applicable columns.
data['reviews_per_month'].fillna(0,inplace=True)
data=data.drop(columns=['name','host_name','last_review'])
data.isna().sum()
# Out:
# id                                0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
#5.	Check which hosts (IDs) have the most listings on Airbnb platform and taking advantage of 
#this service. Display in ascending order. 
data.host_id.nunique()
# Out:
# 37457

# %%
a=data[['host_id','calculated_host_listings_count']].groupby('host_id').sum()

# %%
a.reset_index(inplace=True)

# %%
a=a.sort_values('calculated_host_listings_count',ascending=True)
a
# Out:
#          host_id  calculated_host_listings_count
# 0           2438                               1
# 23768   48823036                               1
# 23767   48819868                               1
# 23766   48818023                               1
# 23765   48817598                               1
# ...          ...                             ...
# 14436   16098958                            9216
# 31079  137358866                           10609
# 19574   30283594                           14641
# 29407  107434423                           53824
# 34646  219517861                          106929
#
# [37457 rows x 2 columns]

# %%
a= data.host_id.value_counts().head(15).sort_values()
a
# Out:
# 190921808     47
# 2856748       49
# 205031545     49
# 120762452     50
# 7503643       52
# 1475015       52
# 200380610     65
# 22541573      87
# 61391963      91
# 16098958      96
# 12243051      96
# 137358866    103
# 30283594     121
# 107434423    232
# 219517861    327
# Name: host_id, dtype: int64

# %%
#sns.barplot(y='calculated_host_listings_count',x='host_id',data=a)

# %%
#6. Plot a bar graph for Host_ID vs Count of Listings. 
#Based on Room_Type, prepare a bar graph for neighbourhood vs Count of Listings 
sns.countplot(x='neighbourhood',hue='room_type',data=data[:100])
# Out:
# <AxesSubplot:xlabel='neighbourhood', ylabel='count'>

# %%
#Plot a bar graph for Host_ID vs Count of Listings.

grouped = data.groupby('host_id').count()['id']
grouped = grouped.sort_values(ascending = False)
N = 50
grouped = grouped[:N]

grouped.plot(kind = 'bar', figsize = (11, 8))

plt.title("Count of Listings by Host ID")
plt.xlabel("Host ID")
plt.ylabel("Count of Listings")

plt.show()

# %%
#Based on Room_Type, prepare a bar graph for neighbourhood vs Count of Listings 

nbh = data.loc[data['neighbourhood'].isin(['Williamsburg','Bedford-Stuyvesant','Harlem','Bushwick','Upper West Side','Hell\'s Kitchen','East Village','Upper East Side','Crown Heights','Midtown'])]

grouped = nbh.groupby(['room_type', 'neighbourhood']).count()['host_id']
grouped = grouped.reset_index()
pivot = grouped.pivot(index = 'neighbourhood', columns = 'room_type', values = 'host_id')

pivot.plot(kind = 'bar', figsize = (15, 8))

plt.title("Count of Listings by Room Type and Neighbourhood")
plt.xlabel("Neighbourhood")
plt.ylabel("Count of Listings")

plt.show()
